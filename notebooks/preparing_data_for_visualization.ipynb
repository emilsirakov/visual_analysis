# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/gapminder_total.csv", index_col=False)
df
# Out:
#                          country  year  total_population  total_fertility  \
# 0                    Afghanistan  1950         7752118.0             7.67
# 1          Akrotiri and Dhekelia  1950           10661.0              NaN
# 2                        Albania  1950         1263171.0             5.80
# 3                        Algeria  1950         8872247.0             7.65
# 4                 American Samoa  1950           18937.0              NaN
# ...                          ...   ...               ...              ...
# 16736                     Zambia  2015        16211767.0             5.59
# 16737                   Zimbabwe  2015        15602751.0             3.35
# 16738                South Sudan  2015        12339812.0              NaN
# 16739                    Curaçao  2015          157203.0              NaN
# 16740  Sint Maarten (Dutch part)  2015           38745.0              NaN
#
#        life_expectancy continent
# 0                26.85      Asia
# ...

# %%
df_subset_2015 = df[df["year"] == 2015]
df_subset_2015
# Out:
#                          country  year  total_population  total_fertility  \
# 16510                Afghanistan  2015        32526562.0             4.47
# 16511                    Albania  2015         2896679.0             1.78
# 16512                    Algeria  2015        39666519.0             2.71
# 16513             American Samoa  2015           55538.0              NaN
# 16514                    Andorra  2015           70473.0              NaN
# ...                          ...   ...               ...              ...
# 16736                     Zambia  2015        16211767.0             5.59
# 16737                   Zimbabwe  2015        15602751.0             3.35
# 16738                South Sudan  2015        12339812.0              NaN
# 16739                    Curaçao  2015          157203.0              NaN
# 16740  Sint Maarten (Dutch part)  2015           38745.0              NaN
#
#        life_expectancy continent
# 16510             53.8      Asia
# ...

# %%
df_subset_2015 = df[(df["year"] == 2014)&(df["country"]=="Nigeria")]
df_subset_2015
# Out:
#        country  year  total_population  total_fertility  life_expectancy  \
# 16430  Nigeria  2014       177475986.0             5.94             63.7
#
#       continent
# 16430    Africa

# %%
Plot the life expectancy vs fertility rate

# %%
sns.scatterplot(x="life_expectancy", y="total_fertility", 
               data=df_subset_2015);

# %%
Step 5
Using matplotlib add a title and labels. Increase the plot size to make it more readable.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="life_expectancy", y="total_fertility", 
               data=df_subset_2015)
plt.title('Life Expectancy vs Fertility Rate')
plt.ylabel("Fertility Rate")
plt.xlabel('Life Expectancy');

# %%
Step 6
Weight the size of the scatter points to the population of each country. This can be 
done using the size parameter in the sns.scatterplot() function.

Tip: the code above is correct but the magnitude of the population is astronomically 
    larger than that of the life expectancy and fertility rate. Use some math to fix this.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="life_expectancy", y="total_fertility",
                 size='total_population', sizes=(50, 250),
               data=df_subset_2015, hue="total_population")
plt.axis([0, 85, 0, 9.5])
plt.title('Life Expectancy vs Fertility Rate')
plt.ylabel("Fertility Rate")
plt.xlabel('Life Expectancy');

# %%
h,l = ax.get_legend_handles_labels()
    plt.legend(h[0:8],l[0:7],bbox_to_anchor=(1, 1), loc=2, frameon=False, fontsize=8)

# %%
plt.figure(figsize=(10, 6))
sns.set_style("darkgrid") 
ax = sns.scatterplot(x="life_expectancy", y="total_fertility",
                 size='total_population', sizes=(50, 250),alpha=0.5,
               data=df_subset_2015, hue="continent")
plt.axis([0, 85, 0, 9.5])
plt.title('Life Expectancy vs Fertility Rate') 
plt.annotate("Bolivia",(df_subset_2015[df_subset_2015["country"]=="Bolivia"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Bolivia"]["total_fertility"]+0.20))
plt.annotate("Germany",(df_subset_2015[df_subset_2015["country"]=="Germany"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Germany"]["total_fertility"]+0.20))
plt.annotate("Nigeria",(df_subset_2015[df_subset["country"]=="Nigeria"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Nigeria"]["total_fertility"]+0.20))
plt.annotate("New Zealand",(df_subset_2015[df_subset_2015["country"]=="New Zealand"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="New Zealand"]["total_fertility"]+0.20))
plt.annotate("Jamaica",(df_subset_2015[df_subset_2015["country"]=="Jamaica"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Jamaica"]["total_fertility"]+0.20))
plt.annotate("Bulgaria",(df_subset_2015[df_subset_2015["country"]=="Bulgaria"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Bulgaria"]["total_fertility"]))
plt.annotate("Japan",(df_subset_2015[df_subset_2015["country"]=="Japan"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Japan"]["total_fertility"]+0.20))
plt.annotate("China",(df_subset_2015[df_subset_2015["country"]=="China"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="China"]["total_fertility"]+0.20))
plt.annotate("Togo",(df_subset_2015[df_subset_2015["country"]=="Togo"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Togo"]["total_fertility"]+0.20))
h,l = ax.get_legend_handles_labels()
plt.legend(h[0:8],l[0:7],bbox_to_anchor=(1, 1), loc=2, frameon=False, fontsize=8)

plt.xticks(rotation=45);
plt.savefig("2015.png", bbox_inches="tight");
#plt.close()

# %%
graphs = []

for year in range(1960, 2016):
    df_subset_2015 = df[df["year"]==year]
    plt.figure(figsize=(10, 6))
    sns.set_style("darkgrid") 
    ax = sns.scatterplot(x="life_expectancy", y="total_fertility",
                 size='total_population', sizes=(50, 250),alpha=0.5,
               data=df_subset_2015, hue="continent")
    plt.axis([0, 85, 0, 9.5])
    plt.title(f'Life Expectancy vs Fertility Rate {year}') 
    plt.annotate("Bolivia",(df_subset_2015[df_subset_2015["country"]=="Bolivia"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Bolivia"]["total_fertility"]+0.20))
    plt.annotate("Germany",(df_subset_2015[df_subset_2015["country"]=="Germany"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Germany"]["total_fertility"]+0.20))
    plt.annotate("Nigeria",(df_subset_2015[df_subset_2015["country"]=="Nigeria"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Nigeria"]["total_fertility"]+0.20))
    plt.annotate("New Zealand",(df_subset_2015[df_subset_2015["country"]=="New Zealand"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="New Zealand"]["total_fertility"]+0.20))
    plt.annotate("Jamaica",(df_subset_2015[df_subset_2015["country"]=="Jamaica"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Jamaica"]["total_fertility"]+0.20))
    plt.annotate("Bulgaria",(df_subset_2015[df_subset_2015["country"]=="Bulgaria"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Bulgaria"]["total_fertility"]))
    plt.annotate("Japan",(df_subset_2015[df_subset_2015["country"]=="Japan"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Japan"]["total_fertility"]+0.20))
    plt.annotate("China",(df_subset_2015[df_subset_2015["country"]=="China"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="China"]["total_fertility"]+0.20))
    plt.annotate("Togo",(df_subset_2015[df_subset_2015["country"]=="Togo"]["life_expectancy"],
                     df_subset_2015[df_subset_2015["country"]=="Togo"]["total_fertility"]+0.20))
    plt.legend(bbox_to_anchor=(1,1), frameon = False)
    h,l = ax.get_legend_handles_labels()
    plt.legend(h[0:8],l[0:7],bbox_to_anchor=(1, 1), loc=2, frameon=False, fontsize=8)
    plt.xticks(rotation=45);
    plt.savefig(f"{year}.png");
    plt.close()

# %%
import imageio.v2 as imageio

# %%
import os

# %%
images = []

for year in range(1960, 2016):
    filename = f"{year}.png"
    img = imageio.imread(filename)
    images.append(img)

imageio.mimsave("test.gif", images, fps=5)
