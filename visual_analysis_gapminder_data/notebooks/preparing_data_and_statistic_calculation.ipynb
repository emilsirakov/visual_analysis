# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
df_continents = pd.read_csv('..\data\continents.csv', sep=';')
df_continents
# Out:
#          continent    country
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
# [194 rows x 2 columns]

# %%
df_continents_count = pd.DataFrame(df_continents["continent"].value_counts())
df_continents_count
# Out:
#                        continent
# Africa                        54
# Europe                        47
# Asia                          44
# North America                 23
# Australia and Oceania         14
# South America                 12

# %%
plt.figure(figsize=(9,3))

plt.barh(df_continents_count.index,df_continents_count["continent"]);

# %%
df_continents_count = (df_continents["continent"].value_counts())
df_continents_count
# Out:
# Africa                   54
# Europe                   47
# Asia                     44
# North America            23
# Australia and Oceania    14
# South America            12
# Name: continent, dtype: int64

# %%
df_continents["continent"].value_counts().plot.barh();

# %%
df_population = pd.read_csv('..\data\population.csv')
df_population
# Out:
#                                    Total population  year  population
# 0                                          Abkhazia  1800         NaN
# 1                                       Afghanistan  1800   3280000.0
# 2                             Akrotiri and Dhekelia  1800         NaN
# 3                                           Albania  1800    410445.0
# 4                                           Algeria  1800   2503218.0
# ...                                             ...   ...         ...
# 22270                             Northern Marianas  2015         NaN
# 22271  South Georgia and the South Sandwich Islands  2015         NaN
# 22272                     US Minor Outlying Islands  2015         NaN
# 22273                                Virgin Islands  2015         NaN
# 22274                                     West Bank  2015         NaN
#
# [22275 rows x 3 columns]

# %%
df_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22275 entries, 0 to 22274
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Total population  22275 non-null  object
#  1   year              22275 non-null  int64
#  2   population        20176 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 522.2+ KB

# %%
df_population.columns
# Out:
# Index(['Total population', 'year', 'population'], dtype='object')

# %%
df_population.columns = ["country", "year", "total_population"]
df_population
# Out:
#                                             country  year  total_population
# 0                                          Abkhazia  1800               NaN
# 1                                       Afghanistan  1800         3280000.0
# 2                             Akrotiri and Dhekelia  1800               NaN
# 3                                           Albania  1800          410445.0
# 4                                           Algeria  1800         2503218.0
# ...                                             ...   ...               ...
# 22270                             Northern Marianas  2015               NaN
# 22271  South Georgia and the South Sandwich Islands  2015               NaN
# 22272                     US Minor Outlying Islands  2015               NaN
# 22273                                Virgin Islands  2015               NaN
# 22274                                     West Bank  2015               NaN
#
# [22275 rows x 3 columns]

# %%
df_population.isnull().sum()
# Out:
# country                0
# year                   0
# total_population    2099
# dtype: int64

# %%
df_population.dropna(inplace=True)

# %%
df_population.isnull().sum()
# Out:
# country             0
# year                0
# total_population    0
# dtype: int64

# %%
df_population.duplicated().sum()
# Out:
# 0

# %%
df_population
# Out:
#                          country  year  total_population
# 1                    Afghanistan  1800         3280000.0
# 3                        Albania  1800          410445.0
# 4                        Algeria  1800         2503218.0
# 5                 American Samoa  1800            8170.0
# 6                        Andorra  1800            2654.0
# ...                          ...   ...               ...
# 22256                     Zambia  2015        16211767.0
# 22257                   Zimbabwe  2015        15602751.0
# 22259                South Sudan  2015        12339812.0
# 22260                    Curaçao  2015          157203.0
# 22261  Sint Maarten (Dutch part)  2015           38745.0
#
# [20176 rows x 3 columns]

# %%
df_population = df_population[df_population["year"] >= 1950]
df_population
# Out:
#                          country  year  total_population
# 4126                 Afghanistan  1950         7752118.0
# 4127       Akrotiri and Dhekelia  1950           10661.0
# 4128                     Albania  1950         1263171.0
# 4129                     Algeria  1950         8872247.0
# 4130              American Samoa  1950           18937.0
# ...                          ...   ...               ...
# 22256                     Zambia  2015        16211767.0
# 22257                   Zimbabwe  2015        15602751.0
# 22259                South Sudan  2015        12339812.0
# 22260                    Curaçao  2015          157203.0
# 22261  Sint Maarten (Dutch part)  2015           38745.0
#
# [16741 rows x 3 columns]

# %%
df_population.to_csv('..\data\population_1950.csv', index=False)

# %%
df_population_1950 = pd.read_csv('..\data\population_1950.csv')
df_population_1950
# Out:
#                          country  year  total_population
# 0                    Afghanistan  1950         7752118.0
# 1          Akrotiri and Dhekelia  1950           10661.0
# 2                        Albania  1950         1263171.0
# 3                        Algeria  1950         8872247.0
# 4                 American Samoa  1950           18937.0
# ...                          ...   ...               ...
# 16736                     Zambia  2015        16211767.0
# 16737                   Zimbabwe  2015        15602751.0
# 16738                South Sudan  2015        12339812.0
# 16739                    Curaçao  2015          157203.0
# 16740  Sint Maarten (Dutch part)  2015           38745.0
#
# [16741 rows x 3 columns]

# %%
df_fertility_rate = pd.read_csv("../data/fertility_rate.csv")
df_fertility_rate
# Out:
#         Total fertility rate  year  fertility
# 0                   Abkhazia  1800        NaN
# 1                Afghanistan  1800       7.00
# 2      Akrotiri and Dhekelia  1800        NaN
# 3                    Albania  1800       4.60
# 4                    Algeria  1800       6.99
# ...                      ...   ...        ...
# 56154                  Yemen  2015       3.83
# 56155             Yugoslavia  2015        NaN
# 56156                 Zambia  2015       5.59
# 56157               Zimbabwe  2015       3.35
# 56158                  Åland  2015        NaN
#
# [56159 rows x 3 columns]

# %%
df_fertility_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56159 entries, 0 to 56158
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Total fertility rate  56159 non-null  object
#  1   year                  56159 non-null  int64
#  2   fertility             43412 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df_fertility_rate.describe(include="O")
# Out:
#        Total fertility rate
# count                 56159
# unique                  259
# top                   Åland
# freq                    431

# %%
df_fertility_rate.isnull().sum()
# Out:
# Total fertility rate        0
# year                        0
# fertility               12747
# dtype: int64

# %%
df_fertility_rate.columns
# Out:
# Index(['Total fertility rate', 'year', 'fertility'], dtype='object')

# %%
df_fertility_rate.rename(columns={'Total fertility rate':'country', 'fertility': 'total_fertility'}, 
            inplace=True)

# %%
df_fertility_rate
# Out:
#                      country  year  total_fertility
# 0                   Abkhazia  1800              NaN
# 1                Afghanistan  1800             7.00
# 2      Akrotiri and Dhekelia  1800              NaN
# 3                    Albania  1800             4.60
# 4                    Algeria  1800             6.99
# ...                      ...   ...              ...
# 56154                  Yemen  2015             3.83
# 56155             Yugoslavia  2015              NaN
# 56156                 Zambia  2015             5.59
# 56157               Zimbabwe  2015             3.35
# 56158                  Åland  2015              NaN
#
# [56159 rows x 3 columns]

# %%
df_fertility_rate.dropna(inplace=True)

# %%
df_fertility_rate
# Out:
#                      country  year  total_fertility
# 1                Afghanistan  1800             7.00
# 3                    Albania  1800             4.60
# 4                    Algeria  1800             6.99
# 7                     Angola  1800             6.93
# 9        Antigua and Barbuda  1800             5.00
# ...                      ...   ...              ...
# 56150                Vietnam  2015             1.70
# 56151  Virgin Islands (U.S.)  2015             2.45
# 56154                  Yemen  2015             3.83
# 56156                 Zambia  2015             5.59
# 56157               Zimbabwe  2015             3.35
#
# [43412 rows x 3 columns]

# %%
df_fertility_rate.isnull().sum()
# Out:
# country            0
# year               0
# total_fertility    0
# dtype: int64

# %%
df_fertility_rate = df_fertility_rate[df_fertility_rate["year"] >= 1950]
df_fertility_rate
# Out:
#                      country  year  total_fertility
# 39001            Afghanistan  1950             7.67
# 39003                Albania  1950             5.80
# 39004                Algeria  1950             7.65
# 39007                 Angola  1950             6.93
# 39009    Antigua and Barbuda  1950             4.45
# ...                      ...   ...              ...
# 56150                Vietnam  2015             1.70
# 56151  Virgin Islands (U.S.)  2015             2.45
# 56154                  Yemen  2015             3.83
# 56156                 Zambia  2015             5.59
# 56157               Zimbabwe  2015             3.35
#
# [13262 rows x 3 columns]

# %%
df_fertility_rate.reset_index(drop=True, inplace=True)
df_fertility_rate
# Out:
#                      country  year  total_fertility
# 0                Afghanistan  1950             7.67
# 1                    Albania  1950             5.80
# 2                    Algeria  1950             7.65
# 3                     Angola  1950             6.93
# 4        Antigua and Barbuda  1950             4.45
# ...                      ...   ...              ...
# 13257                Vietnam  2015             1.70
# 13258  Virgin Islands (U.S.)  2015             2.45
# 13259                  Yemen  2015             3.83
# 13260                 Zambia  2015             5.59
# 13261               Zimbabwe  2015             3.35
#
# [13262 rows x 3 columns]

# %%
df_fertility_rate.to_csv("../data/fertility_1950.csv", index=False)

# %%
life_expectancy = pd.read_excel("../data/life_expectancy.xls")
life_expectancy
# Out:
#              Life expectancy  year  life expectancy
# 0                   Abkhazia  1800              NaN
# 1                Afghanistan  1800            28.21
# 2      Akrotiri and Dhekelia  1800              NaN
# 3                    Albania  1800            35.40
# 4                    Algeria  1800            28.82
# ...                      ...   ...              ...
# 56415             Yugoslavia  2016              NaN
# 56416                 Zambia  2016            57.10
# 56417               Zimbabwe  2016            61.69
# 56418                  Åland  2016              NaN
# 56419            South Sudan  2016            56.10
#
# [56420 rows x 3 columns]

# %%
life_expectancy.isnull().sum()
# Out:
# Life expectancy        0
# year                   0
# life expectancy    12563
# dtype: int64

# %%
life_expectancy.columns
# Out:
# Index(['Life expectancy', 'year', 'life expectancy'], dtype='object')

# %%
life_expectancy.rename(columns={'Life expectancy':'country', 'life expectancy': 'life_expectancy'}, 
            inplace=True)
life_expectancy
# Out:
#                      country  year  life_expectancy
# 0                   Abkhazia  1800              NaN
# 1                Afghanistan  1800            28.21
# 2      Akrotiri and Dhekelia  1800              NaN
# 3                    Albania  1800            35.40
# 4                    Algeria  1800            28.82
# ...                      ...   ...              ...
# 56415             Yugoslavia  2016              NaN
# 56416                 Zambia  2016            57.10
# 56417               Zimbabwe  2016            61.69
# 56418                  Åland  2016              NaN
# 56419            South Sudan  2016            56.10
#
# [56420 rows x 3 columns]

# %%
life_expectancy.dropna(inplace=True)
life_expectancy
# Out:
#                      country  year  life_expectancy
# 1                Afghanistan  1800            28.21
# 3                    Albania  1800            35.40
# 4                    Algeria  1800            28.82
# 7                     Angola  1800            26.98
# 9        Antigua and Barbuda  1800            33.54
# ...                      ...   ...              ...
# 56411  Virgin Islands (U.S.)  2016            80.82
# 56414                  Yemen  2016            64.92
# 56416                 Zambia  2016            57.10
# 56417               Zimbabwe  2016            61.69
# 56419            South Sudan  2016            56.10
#
# [43857 rows x 3 columns]

# %%
life_expectancy = life_expectancy[life_expectancy["year"] >= 1950]
life_expectancy
# Out:
#                      country  year  life_expectancy
# 39001            Afghanistan  1950            26.85
# 39003                Albania  1950            54.48
# 39004                Algeria  1950            42.77
# 39007                 Angola  1950            30.70
# 39009    Antigua and Barbuda  1950            57.97
# ...                      ...   ...              ...
# 56411  Virgin Islands (U.S.)  2016            80.82
# 56414                  Yemen  2016            64.92
# 56416                 Zambia  2016            57.10
# 56417               Zimbabwe  2016            61.69
# 56419            South Sudan  2016            56.10
#
# [13707 rows x 3 columns]

# %%
life_expectancy.reset_index(drop=True, inplace=True)
life_expectancy
# Out:
#                      country  year  life_expectancy
# 0                Afghanistan  1950            26.85
# 1                    Albania  1950            54.48
# 2                    Algeria  1950            42.77
# 3                     Angola  1950            30.70
# 4        Antigua and Barbuda  1950            57.97
# ...                      ...   ...              ...
# 13702  Virgin Islands (U.S.)  2016            80.82
# 13703                  Yemen  2016            64.92
# 13704                 Zambia  2016            57.10
# 13705               Zimbabwe  2016            61.69
# 13706            South Sudan  2016            56.10
#
# [13707 rows x 3 columns]

# %%
life_expectancy.to_csv("../data/life_expectancy_1950.csv", index=False)

# %%
life_df = pd.read_csv('../data/life_expectancy_1950.csv', index_col=0)
life_df
# Out:
#                        year  life_expectancy
# country
# Afghanistan            1950            26.85
# Albania                1950            54.48
# Algeria                1950            42.77
# Angola                 1950            30.70
# Antigua and Barbuda    1950            57.97
# ...                     ...              ...
# Virgin Islands (U.S.)  2016            80.82
# Yemen                  2016            64.92
# Zambia                 2016            57.10
# Zimbabwe               2016            61.69
# South Sudan            2016            56.10
#
# [13707 rows x 2 columns]

# %%
life_expectancy_mean = life_df["life_expectancy"].mean()
life_expectancy_mean
# Out:
# 62.98883344276646

# %%
life_expectancy_mean_2000 = life_df.loc[life_df["year"] ==2000,["life_expectancy"]].mean()
#life_expectancy_mean_2000 = life_expectancy_mean_2000["life_expectancy"].mean()
life_expectancy_mean_2000
# Out:
# life_expectancy    68.077703
# dtype: float64

# %%
life_expectancy_median_1995 = life_df.loc[life_df["year"] ==1995,["life_expectancy"]].median()
life_expectancy_median_1995
# Out:
# life_expectancy    70.0
# dtype: float64

# %%
life_expectancy_std = life_df["life_expectancy"].std()
life_expectancy_std
# Out:
# 11.89557179977113

# %%
life_df["life_expectancy"].max()
# Out:
# 84.8

# %%
life_df[life_df["life_expectancy"] == life_df["life_expectancy"].max()]
# Out:
#          year  life_expectancy
# country
# Andorra  2013             84.8
# Andorra  2014             84.8
# Andorra  2015             84.8
# Andorra  2016             84.8

# %%
life_df["life_expectancy"].min()
# Out:
# 13.2

# %%
life_df[life_df["life_expectancy"] == life_df["life_expectancy"].min()]
# Out:
#          year  life_expectancy
# country
# Rwanda   1994             13.2

# %%
life_df["life_expectancy"].quantile(0.9)
# Out:
# 76.4

# %%
life_df.describe()
# Out:
#                year  life_expectancy
# count  13707.000000     13707.000000
# mean    1983.251550        62.988833
# std       19.364466        11.895572
# min     1950.000000        13.200000
# 25%     1966.000000        54.815000
# 50%     1983.000000        65.570000
# 75%     2000.000000        72.230000
# max     2016.000000        84.800000
